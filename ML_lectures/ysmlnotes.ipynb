# %%
% Apply common average reference to all datasets
for i = 1:length(ALLEEG)
    ALLEEG(i) = pop_reref(ALLEEG(i), []);
end
[ALLEEG EEG CURRENTSET] = eeg_store(ALLEEG, EEG, CURRENTSET);
eeglab redraw
